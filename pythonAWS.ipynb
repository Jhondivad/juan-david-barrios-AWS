# %%
print('hola mundo')
# Out:
# hola mundo

# %%
print(3+5)
# Out:
# 8

# %%
print('hola'+'mundo')
# Out:
# holamundo

# %%
nombre= 'Átame'
ano= 1989
visto ='12 de diciembre 1989'

print ("La película: {} fue estrenada en el año {} y vista el {}".format(nombre, ano, visto))
# Out:
# La película: Átame fue estrenada en el año 1989 y vista el 12 de diciembre 1989

# %%
nombres= [
    "The Shawshank Redemption",
    "The Dark Knight",
    "Inception",
    "Pulp Fiction",
    "The Matrix",
    "Interstellar",
    "Parasite",
    "Gladiator",
    "Titanic",
    "The Lord of the Rings: The Fellowship of the Ring"
]

annos= [
    1994,
    2008,
    2010,
    1994,
    1999,
    2014,
    2019,
    2000,
    1997,
    2001
]

vista= [
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False
]

for i, (nombres, annos, vista) in enumerate(zip(nombres, annos, vista), start=1):
    print(f"{i}. nombre:{nombres} año:{annos} vista:{vista}")
# Out:
# 1. nombre:The Shawshank Redemption anno:1994 vista:True
# 2. nombre:The Dark Knight anno:2008 vista:False
# 3. nombre:Inception anno:2010 vista:True
# 4. nombre:Pulp Fiction anno:1994 vista:False
# 5. nombre:The Matrix anno:1999 vista:True
# 6. nombre:Interstellar anno:2014 vista:False
# 7. nombre:Parasite anno:2019 vista:True
# 8. nombre:Gladiator anno:2000 vista:False
# 9. nombre:Titanic anno:1997 vista:True
# 10. nombre:The Lord of the Rings: The Fellowship of the Ring anno:2001 vista:False
